# %% [markdown]
# # Lab 03: Fun with `pandas`!

# %% [markdown]
# Below are some exercises to get you working with `pandas` to manipulate data. As always, get as far as you can, and ask for help when you need it! Your teacher (me), you instructor, and your classmates are all here to help each other get better at coding. Getting the code to work is important, but do also take the time to make sure you understand what the commands are doing. This time, (with the exception of the Stroop challenge), all I've given you is the code to download the data. Then you are on your own. For the Stroop challenge, I gave the you code for the first step—after that, it's up to you :-)

# %% [markdown]
# ## Music sales challenge
#
# Write a script that:
#
# 1. Combines the tables of best-selling physical singles and best-selling digital singles on the Wikipedia page "List_of_best-selling_singles"
# 2. Adds a column which marks whether each row is from the list of physical singles or digital singles
# 3. Outputs the artist and single name for the year you were born. If there is no entry for that year, take the closest year after you were born.
# 4. Outputs the artist and single name for the year you were 15 years old.

# %%
# Starter code...

# %pip install lxml
import pandas as pd

rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_best-selling_singles")
# Out:
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
rawdata

# %%
physical_df = rawdata[0]

# %%
physical_df
# Out:
#                                   Artist  \
# 0                            Bing Crosby
# 1                             Elton John
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 6                          Elvis Presley
# 7                         USA for Africa
# 8                          The Ink Spots
# 9                            Celine Dion
# 10                          Mariah Carey
# 11                               Baccara
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# 5                            "I Will Always Love You"      1992
# 6                                 "It's Now or Never"      1960
# 7                                  "We Are the World"      1985
# 8                                  "If I Didn't Care"      1939
# 9                               "My Heart Will Go On"      1997
# 10                  "All I Want For Christmas Is You"      1994
# 11                            "Yes Sir, I Can Boogie"      1977
# 12                "(Everything I Do) I Do It for You"      1991
# 13                       "You're the One That I Want"      1978
#
#        Sales (in millions)  Source
# 0                       50     [1]
# 1                       33     [1]
# 2                       30     [2]
# 3                       30     [3]
# 4                       25  [4][5]
# 5                       24     [6]
# 6                       20  [7][8]
# 7                       20     [9]
# 8   19[disputed – discuss]    [10]
# 9                       18    [11]
# 10                      16    [12]
# 11                      16    [13]
# 12                      15    [14]
# 13                      15    [15]

# %%
digital_df = rawdata[3]

# %%
digital_df
# Out:
#                                  Artist                      Single  Released  \
# 0                            Ed Sheeran              "Shape of You"      2017
# 1     Luis Fonsi featuring Daddy Yankee                 "Despacito"      2017
# 2               Rihanna featuring Drake                      "Work"      2016
# 3         The Chainsmokers and Coldplay  "Something Just Like This"      2017
# 4                            Ed Sheeran                   "Perfect"      2017
# 5    Wiz Khalifa featuring Charlie Puth             "See You Again"      2015
# 6     The Chainsmokers featuring Halsey                    "Closer"      2016
# 7                                 Adele       "Rolling in the Deep"      2011
# 8      Mark Ronson featuring Bruno Mars               "Uptown Funk"      2015
# 9                         Billie Eilish                   "Bad Guy"      2019
# 10                           Ed Sheeran         "Thinking Out Loud"      2015
# 11  Camila Cabello featuring Young Thug                    "Havana"      2017
# 12                            Lil Nas X             "Old Town Road"      2018
# 13                     Carly Rae Jepsen             "Call Me Maybe"      2011
# 14                         Taylor Swift                "Love Story"      2008
# 15                                Adele          "Someone Like You"      2011
# 16                              Rihanna                 "Needed Me"      2016
# 17      Shawn Mendes and Camila Cabello                  "Señorita"      2019
# 18                      Imagine Dragons               "Radioactive"      2012
# 19                      Imagine Dragons                  "Believer"      2017
# 20                                Drake                "God's Plan"      2018
#
#    Sales (in millions)        Source
# 0              41.5[a]      [46][47]
# 1              36.1[a]      [46][47]
# 2              32.5[a]          [48]
# 3              21.5[a]      [46][47]
# 4              21.4[a]      [46][47]
# 5              20.9[a]          [49]
# 6              20.7[a]      [50][46]
# 7                 20.6  [51][52][53]
# 8                20[a]          [49]
# 9              19.5[a]          [54]
# 10             19.5[a]          [49]
# 11             19.0[a]      [46][47]
# 12             18.4[a]          [54]
# 13                18.0          [55]
# 14             18.0[a]          [56]
# 15                17.0          [57]
# 16             17.0[a]          [48]
# 17             16.1[a]          [54]
# 18               16[a]          [58]
# 19             15.4[a]      [59][60]
# 20             15.3[a]          [47]

# %%
merged_df = pd.concat([physical_df, digital_df])
list(merged_df)
merged_df
# Out:
#                                   Artist  \
# 0                            Bing Crosby
# 1                             Elton John
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 6                          Elvis Presley
# 7                         USA for Africa
# 8                          The Ink Spots
# 9                            Celine Dion
# 10                          Mariah Carey
# 11                               Baccara
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
# 0                             Ed Sheeran
# 1      Luis Fonsi featuring Daddy Yankee
# 2                Rihanna featuring Drake
# 3          The Chainsmokers and Coldplay
# 4                             Ed Sheeran
# 5     Wiz Khalifa featuring Charlie Puth
# 6      The Chainsmokers featuring Halsey
# 7                                  Adele
# 8       Mark Ronson featuring Bruno Mars
# 9                          Billie Eilish
# 10                            Ed Sheeran
# 11   Camila Cabello featuring Young Thug
# 12                             Lil Nas X
# 13                      Carly Rae Jepsen
# 14                          Taylor Swift
# 15                                 Adele
# 16                               Rihanna
# 17       Shawn Mendes and Camila Cabello
# 18                       Imagine Dragons
# 19                       Imagine Dragons
# 20                                 Drake
#
#                                                Single  Released  \
# 0                                   "white christmas"      1942
# 1   "something about the way you look tonight"/"ca...      1997
# 2                                      "silent night"      1935
# 3                                   "petit papa noël"      1946
# 4                             "rock around the clock"      1954
# 5                            "i will always love you"      1992
# 6                                 "it's now or never"      1960
# 7                                  "we are the world"      1985
# 8                                  "if i didn't care"      1939
# 9                               "my heart will go on"      1997
# 10                  "all i want for christmas is you"      1994
# 11                            "yes sir, i can boogie"      1977
# 12                "(everything i do) i do it for you"      1991
# 13                       "you're the one that i want"      1978
# 0                                      "shape of you"      2017
# 1                                         "despacito"      2017
# 2                                              "work"      2016
# 3                          "something just like this"      2017
# 4                                           "perfect"      2017
# 5                                     "see you again"      2015
# 6                                            "closer"      2016
# 7                               "rolling in the deep"      2011
# 8                                       "uptown funk"      2015
# 9                                           "bad guy"      2019
# 10                                "thinking out loud"      2015
# 11                                           "havana"      2017
# 12                                    "old town road"      2018
# 13                                    "call me maybe"      2011
# 14                                       "love story"      2008
# 15                                 "someone like you"      2011
# 16                                        "needed me"      2016
# 17                                         "señorita"      2019
# 18                                      "radioactive"      2012
# 19                                         "believer"      2017
# 20                                       "god's plan"      2018
#
#        Sales (in millions)        Source
# 0                       50           [1]
# 1                       33           [1]
# 2                       30           [2]
# 3                       30           [3]
# 4                       25        [4][5]
# 5                       24           [6]
# 6                       20        [7][8]
# 7                       20           [9]
# 8   19[disputed – discuss]          [10]
# 9                       18          [11]
# 10                      16          [12]
# 11                      16          [13]
# 12                      15          [14]
# 13                      15          [15]
# 0                  41.5[a]      [46][47]
# 1                  36.1[a]      [46][47]
# 2                  32.5[a]          [48]
# 3                  21.5[a]      [46][47]
# 4                  21.4[a]      [46][47]
# 5                  20.9[a]          [49]
# 6                  20.7[a]      [50][46]
# 7                     20.6  [51][52][53]
# 8                    20[a]          [49]
# 9                  19.5[a]          [54]
# 10                 19.5[a]          [49]
# 11                 19.0[a]      [46][47]
# 12                 18.4[a]          [54]
# 13                    18.0          [55]
# 14                 18.0[a]          [56]
# 15                    17.0          [57]
# 16                 17.0[a]          [48]
# 17                 16.1[a]          [54]
# 18                   16[a]          [58]
# 19                 15.4[a]      [59][60]
# 20                 15.3[a]          [47]

# %%
merged_df["Digital or physical?"] = "who knows" #creating column for later for loop
merged_df['Sales (in millions)'] = merged_df['Sales (in millions)'].replace(r'[^\d.]+', '', regex=True) #removing letters
merged_df['Sales (in millions)'] = pd.to_numeric(merged_df['Sales (in millions)'], errors='coerce') #making sure values are numeric
merged_df = merged_df.sort_values(by="Sales (in millions)", ascending=False) #sorting by highest value in sales column
merged_df
# Out:
#                                   Artist  \
# 0                            Bing Crosby
# 0                             Ed Sheeran
# 1      Luis Fonsi featuring Daddy Yankee
# 1                             Elton John
# 2                Rihanna featuring Drake
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 3          The Chainsmokers and Coldplay
# 4                             Ed Sheeran
# 5     Wiz Khalifa featuring Charlie Puth
# 6      The Chainsmokers featuring Halsey
# 7                                  Adele
# 6                          Elvis Presley
# 8       Mark Ronson featuring Bruno Mars
# 7                         USA for Africa
# 10                            Ed Sheeran
# 9                          Billie Eilish
# 11   Camila Cabello featuring Young Thug
# 8                          The Ink Spots
# 12                             Lil Nas X
# 13                      Carly Rae Jepsen
# 9                            Celine Dion
# 14                          Taylor Swift
# 15                                 Adele
# 16                               Rihanna
# 17       Shawn Mendes and Camila Cabello
# 18                       Imagine Dragons
# 11                               Baccara
# 10                          Mariah Carey
# 19                       Imagine Dragons
# 20                                 Drake
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
#
#                                                Single  Released  \
# 0                                   "white christmas"      1942
# 0                                      "shape of you"      2017
# 1                                         "despacito"      2017
# 1   "something about the way you look tonight"/"ca...      1997
# 2                                              "work"      2016
# 2                                      "silent night"      1935
# 3                                   "petit papa noël"      1946
# 4                             "rock around the clock"      1954
# 5                            "i will always love you"      1992
# 3                          "something just like this"      2017
# 4                                           "perfect"      2017
# 5                                     "see you again"      2015
# 6                                            "closer"      2016
# 7                               "rolling in the deep"      2011
# 6                                 "it's now or never"      1960
# 8                                       "uptown funk"      2015
# 7                                  "we are the world"      1985
# 10                                "thinking out loud"      2015
# 9                                           "bad guy"      2019
# 11                                           "havana"      2017
# 8                                  "if i didn't care"      1939
# 12                                    "old town road"      2018
# 13                                    "call me maybe"      2011
# 9                               "my heart will go on"      1997
# 14                                       "love story"      2008
# 15                                 "someone like you"      2011
# 16                                        "needed me"      2016
# 17                                         "señorita"      2019
# 18                                      "radioactive"      2012
# 11                            "yes sir, i can boogie"      1977
# 10                  "all i want for christmas is you"      1994
# 19                                         "believer"      2017
# 20                                       "god's plan"      2018
# 12                "(everything i do) i do it for you"      1991
# 13                       "you're the one that i want"      1978
#
#     Sales (in millions)        Source Digital or physical?
# 0                  50.0           [1]            who knows
# 0                  41.5      [46][47]            who knows
# 1                  36.1      [46][47]            who knows
# 1                  33.0           [1]            who knows
# 2                  32.5          [48]            who knows
# 2                  30.0           [2]            who knows
# 3                  30.0           [3]            who knows
# 4                  25.0        [4][5]            who knows
# 5                  24.0           [6]            who knows
# 3                  21.5      [46][47]            who knows
# 4                  21.4      [46][47]            who knows
# 5                  20.9          [49]            who knows
# 6                  20.7      [50][46]            who knows
# 7                  20.6  [51][52][53]            who knows
# 6                  20.0        [7][8]            who knows
# 8                  20.0          [49]            who knows
# 7                  20.0           [9]            who knows
# 10                 19.5          [49]            who knows
# 9                  19.5          [54]            who knows
# 11                 19.0      [46][47]            who knows
# 8                  19.0          [10]            who knows
# 12                 18.4          [54]            who knows
# 13                 18.0          [55]            who knows
# 9                  18.0          [11]            who knows
# 14                 18.0          [56]            who knows
# 15                 17.0          [57]            who knows
# 16                 17.0          [48]            who knows
# 17                 16.1          [54]            who knows
# 18                 16.0          [58]            who knows
# 11                 16.0          [13]            who knows
# 10                 16.0          [12]            who knows
# 19                 15.4      [59][60]            who knows
# 20                 15.3          [47]            who knows
# 12                 15.0          [14]            who knows
# 13                 15.0          [15]            who knows

# %%
#i'm having trouble with the loop code so this is me trying to debug
merged_df['Single'] = merged_df['Single'].str.strip().str.lower()
digital_df['Single'] = digital_df['Single'].str.strip().str.lower()
physical_df['Single'] = physical_df['Single'].str.strip().str.lower()

# %%
#my loop didnt seem to work so i got some code from gpt to check whether it was..
#weirdly, the gpt code lets me know that it is assigning physical and digital correctly
#but when i load merged_df again, they're assigned wrong
#must be something about saving the changes - i've messed around with it but can't fix it

for idx, single in merged_df.iterrows():
    # Debugging: Print the current single being checked
    print(f"Checking: {single['Single']}")
    
    if single['Single'] in digital_df['Single'].values:
        print(f"{single['Single']} is digital")
        merged_df.at[idx, 'Digital or physical?'] = 'digital'
    elif single['Single'] in physical_df['Single'].values:
        print(f"{single['Single']} is physical")
        merged_df.at[idx, 'Digital or physical?'] = 'physical'

merged_df
# Out:
# Checking: "white christmas"
# "white christmas" is physical
# Checking: "shape of you"
# "shape of you" is digital
# Checking: "despacito"
# "despacito" is digital
# Checking: "something about the way you look tonight"/"candle in the wind 1997"
# "something about the way you look tonight"/"candle in the wind 1997" is physical
# Checking: "work"
# "work" is digital
# Checking: "silent night"
# "silent night" is physical
# Checking: "petit papa noël"
# "petit papa noël" is physical
# Checking: "rock around the clock"
# "rock around the clock" is physical
# Checking: "i will always love you"
# "i will always love you" is physical
# Checking: "something just like this"
# "something just like this" is digital
# Checking: "perfect"
# "perfect" is digital
# Checking: "see you again"
# "see you again" is digital
# Checking: "closer"
# "closer" is digital
# Checking: "rolling in the deep"
# "rolling in the deep" is digital
# Checking: "it's now or never"
# "it's now or never" is physical
# Checking: "uptown funk"
# "uptown funk" is digital
# Checking: "we are the world"
# "we are the world" is physical
# Checking: "thinking out loud"
# "thinking out loud" is digital
# Checking: "bad guy"
# "bad guy" is digital
# Checking: "havana"
# "havana" is digital
# Checking: "if i didn't care"
# "if i didn't care" is physical
# Checking: "old town road"
# "old town road" is digital
# Checking: "call me maybe"
# "call me maybe" is digital
# Checking: "my heart will go on"
# "my heart will go on" is physical
# Checking: "love story"
# "love story" is digital
# Checking: "someone like you"
# "someone like you" is digital
# Checking: "needed me"
# "needed me" is digital
# Checking: "señorita"
# "señorita" is digital
# Checking: "radioactive"
# "radioactive" is digital
# Checking: "yes sir, i can boogie"
# "yes sir, i can boogie" is physical
# Checking: "all i want for christmas is you"
# "all i want for christmas is you" is physical
# Checking: "believer"
# "believer" is digital
# Checking: "god's plan"
# "god's plan" is digital
# Checking: "(everything i do) i do it for you"
# "(everything i do) i do it for you" is physical
# Checking: "you're the one that i want"
# "you're the one that i want" is physical
#                                   Artist  \
# 0                            Bing Crosby
# 0                             Ed Sheeran
# 1      Luis Fonsi featuring Daddy Yankee
# 1                             Elton John
# 2                Rihanna featuring Drake
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 3          The Chainsmokers and Coldplay
# 4                             Ed Sheeran
# 5     Wiz Khalifa featuring Charlie Puth
# 6      The Chainsmokers featuring Halsey
# 7                                  Adele
# 6                          Elvis Presley
# 8       Mark Ronson featuring Bruno Mars
# 7                         USA for Africa
# 10                            Ed Sheeran
# 9                          Billie Eilish
# 11   Camila Cabello featuring Young Thug
# 8                          The Ink Spots
# 12                             Lil Nas X
# 13                      Carly Rae Jepsen
# 9                            Celine Dion
# 14                          Taylor Swift
# 15                                 Adele
# 16                               Rihanna
# 17       Shawn Mendes and Camila Cabello
# 18                       Imagine Dragons
# 11                               Baccara
# 10                          Mariah Carey
# 19                       Imagine Dragons
# 20                                 Drake
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
#
#                                                Single  Released  \
# 0                                   "white christmas"      1942
# 0                                      "shape of you"      2017
# 1                                         "despacito"      2017
# 1   "something about the way you look tonight"/"ca...      1997
# 2                                              "work"      2016
# 2                                      "silent night"      1935
# 3                                   "petit papa noël"      1946
# 4                             "rock around the clock"      1954
# 5                            "i will always love you"      1992
# 3                          "something just like this"      2017
# 4                                           "perfect"      2017
# 5                                     "see you again"      2015
# 6                                            "closer"      2016
# 7                               "rolling in the deep"      2011
# 6                                 "it's now or never"      1960
# 8                                       "uptown funk"      2015
# 7                                  "we are the world"      1985
# 10                                "thinking out loud"      2015
# 9                                           "bad guy"      2019
# 11                                           "havana"      2017
# 8                                  "if i didn't care"      1939
# 12                                    "old town road"      2018
# 13                                    "call me maybe"      2011
# 9                               "my heart will go on"      1997
# 14                                       "love story"      2008
# 15                                 "someone like you"      2011
# 16                                        "needed me"      2016
# 17                                         "señorita"      2019
# 18                                      "radioactive"      2012
# 11                            "yes sir, i can boogie"      1977
# 10                  "all i want for christmas is you"      1994
# 19                                         "believer"      2017
# 20                                       "god's plan"      2018
# 12                "(everything i do) i do it for you"      1991
# 13                       "you're the one that i want"      1978
#
#     Sales (in millions)        Source Digital or physical?
# 0                  50.0           [1]              digital
# 0                  41.5      [46][47]              digital
# 1                  36.1      [46][47]             physical
# 1                  33.0           [1]             physical
# 2                  32.5          [48]             physical
# 2                  30.0           [2]             physical
# 3                  30.0           [3]              digital
# 4                  25.0        [4][5]              digital
# 5                  24.0           [6]              digital
# 3                  21.5      [46][47]              digital
# 4                  21.4      [46][47]              digital
# 5                  20.9          [49]              digital
# 6                  20.7      [50][46]             physical
# 7                  20.6  [51][52][53]             physical
# 6                  20.0        [7][8]             physical
# 8                  20.0          [49]             physical
# 7                  20.0           [9]             physical
# 10                 19.5          [49]             physical
# 9                  19.5          [54]             physical
# 11                 19.0      [46][47]             physical
# 8                  19.0          [10]             physical
# 12                 18.4          [54]             physical
# 13                 18.0          [55]             physical
# 9                  18.0          [11]             physical
# 14                 18.0          [56]              digital
# 15                 17.0          [57]              digital
# 16                 17.0          [48]              digital
# 17                 16.1          [54]              digital
# 18                 16.0          [58]              digital
# 11                 16.0          [13]             physical
# 10                 16.0          [12]             physical
# 19                 15.4      [59][60]              digital
# 20                 15.3          [47]              digital
# 12                 15.0          [14]             physical
# 13                 15.0          [15]             physical

# %%
print(merged_df.info())
print(merged_df['Released'].unique())

merged_df[merged_df['Released'] == '1994']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Artist               35 non-null     object
#  1   Single               35 non-null     object
#  2   Released             35 non-null     int64
#  3   Sales (in millions)  35 non-null     object
#  4   Source               35 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB
# None
# [1942 1997 1935 1946 1954 1992 1960 1985 1939 1994 1977 1991 1978 2017
#  2016 2015 2011 2019 2018 2008 2012]
# Empty DataFrame
# Columns: [Artist, Single, Released, Sales (in millions), Source]
# Index: []

# %% [markdown]
# ## Space challenge
#
# 1. Make a single dataframe that combines the space missions from the 1950's to the 2020's
# 2. Write a script that returns the year with the most launches
# 3. Write a script that returns the most common month for launches
# 4. Write a script that ranks the months from most launches to fewest launches

# %%
# Starter code...

#%pip install lxml
import pandas as pd

rawdata = pd.read_html("https://en.wikipedia.org/wiki/Timeline_of_Solar_System_exploration")

# %% [markdown]
# ## Supervillain challenge
#
# 1. Write a script that combines the tables showing supervillain debuts from the 30's through the 2010's
# 2. Write a script that ranks each decade in terms of how many supervillains debuted in that decade
# 3. Write a script that ranks the different comics companies in terms of how many supervillains they have, and display the results in a nice table (pandas dataframe)

# %%
rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_comic_book_supervillain_debuts")

# %% [markdown]
# ## Stroop challenge
#
# Every year between 2015 and 2021, the students in my Language, Cognition, and the Brain course participated in a version of the Stroop task. Using a stopwatch (ok, using their phones), they recorded how fast they could say a list of things (either reading or naming colors or color words). The column names mean "Reading with No Interference", "Naming with Interference", "Naming with No Interference", and "Reading with Interference". The times are in seconds.
#
# ### Stroop challenge 1:
# Transform these data from wide format to long format, so that the result is a dataframe with
# - 1 column named "Participant_id" with a unique number for each participant (you can use the row indices)
# - 1 column named "Year" with the year data
# - 1 column named "Task" that shows which task they were doing
# - 1 column named "RT" that shows their response time

# %%
# Starter code 1...

df = pd.read_csv("https://raw.githubusercontent.com/ethanweed/Stroop/master/Stroop-raw-over-the-years.csv")
df.head()

# %%
# Starter code 2...

# Make a new column using the dataframe indices as particpant numbers

df.index.name = 'Participant_id'
df = df.reset_index()

#df.reset_index(inplace = True)
# NOTE: This line does exactly the same thing as the line above:
# it replaces the original df with a new df with the updated index. That's what
# "inplace = True" means. Or, you can just assign the dataframe with the updated index
# to a new dataframe with the same name as the old dataframe, which is what I did above.
# The end result is the same.

df

# %% [markdown]
# ## Stroop challenge 2 (Advanced!!!):
#
# Make a new dataframe which shows the mean response time (in seconds) for each task for each year.
